# %%
# !pip install beautifulsoup4

# %%
# !pip install lxml
# Out:
# ...
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 435.7 kB/s eta 0:00:09
#     --------------------------------------- 0.1/3.8 MB 880.9 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.8 MB 1.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.4/3.8 MB 1.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.5/3.8 MB 2.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.7/3.8 MB 2.6 MB/s eta 0:00:02
#    --------- ------------------------------ 0.9/3.8 MB 2.8 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 3.4 MB/s eta 0:00:01
# ...

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_companies_of_Bangladesh'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of companies of Bangladesh - Wikipedia</title>
# ...

# %%
table = soup.find('table')

# %%
title = table.find_all('th')

# %%
table_titles = [titles.text.strip() for titles in title]

# %%
table_titles
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
import pandas as pd

# %%
DF = pd.DataFrame(columns = table_titles)
DF
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Sector, Headquarters, Founded, Notes]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:] :
    row_data = row.find_all('td')
    datas = [data.text.strip() for data in row_data]
    length = len(DF)
    DF.loc[length] = datas

# %%
DF
# Out:
#                                    Name           Industry  \
# 0                    A K Khan & Company      Conglomerates
# 1                                Aarong     Consumer goods
# 2                      Abul Khair Group      Conglomerates
# 3                    Adamjee Jute Mills     Consumer goods
# 4    Advanced Chemical Industries (ACI)      Conglomerates
# ..                                  ...                ...
# 138                        United Group      Conglomerates
# 139                  US-Bangla Airlines  Consumer services
# 140                 Uttara Bank Limited         Financials
# 141                              Walton      Conglomerates
# 142             Western Marine Shipyard        Industrials
#
#                            Sector Headquarters Founded  \
# 0                               -   Chittagong    1945
# 1      Personal & household goods        Dhaka    1978
# 2                               -   Chattogram    1953
# ...

# %%
DF.to_csv(r'C:\Users\sayeem\Downloads\data analysis\webscraping.csv', index = False)
